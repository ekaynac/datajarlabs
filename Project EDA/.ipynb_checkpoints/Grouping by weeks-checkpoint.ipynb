# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.mstats import winsorize
from scipy.stats import zscore

# %%
df = pd.read_csv("datacheck15-4-20.csv",decimal=".")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Country Name  total_cases  \
# 0              0             0               0  Afghanistan            1
# 1              1             1               1  Afghanistan            1
# 2              2             2               2  Afghanistan            1
# 3              3             3               3  Afghanistan            1
# 4              4             4               4  Afghanistan            1
# ...          ...           ...             ...          ...          ...
# 5095        5095          5095            5095     Zimbabwe            8
# 5096        5096          5096            5096     Zimbabwe            8
# 5097        5097          5097            5097     Zimbabwe            9
# 5098        5098          5098            5098     Zimbabwe            9
# 5099        5099          5099            5099     Zimbabwe            9
#
#       total_deaths continent  population  Year  \
# ...

# %% [markdown]
# After this point we need to seperate our data by amount of data we have. We will examine our data seperately.

# %%
del df["Unnamed: 0"]
del df["Unnamed: 0.1"]
del df["Unnamed: 0.1.1"]
df
# Out:
#      Country Name  total_cases  total_deaths continent  population  Year  \
# 0     Afghanistan            1             0      Asia    38928341  2020
# 1     Afghanistan            1             0      Asia    38928341  2020
# 2     Afghanistan            1             0      Asia    38928341  2020
# 3     Afghanistan            1             0      Asia    38928341  2020
# 4     Afghanistan            1             0      Asia    38928341  2020
# ...           ...          ...           ...       ...         ...   ...
# 5095     Zimbabwe            8             1    Africa    14862927  2020
# 5096     Zimbabwe            8             1    Africa    14862927  2020
# 5097     Zimbabwe            9             1    Africa    14862927  2020
# 5098     Zimbabwe            9             1    Africa    14862927  2020
# 5099     Zimbabwe            9             1    Africa    14862927  2020
#
#       Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# ...

# %%
df_2weeks = df
df_4weeks = df[df["4 weeks"]]
df_8weeks = df[df["+8 weeks"]]

# %%
countries_4 = df.groupby(by="Country Name").count() > 28
count_4weeks = countries_4[countries_4["total_cases"]].index

count_4weeks
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Argentina', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahrain', 'Belarus', 'Belgium', 'Brazil',
#        'Cambodia', 'Canada', 'Chile', 'China', 'Costa Rica', 'Croatia',
#        'Czech Republic', 'Denmark', 'Ecuador', 'Estonia', 'Finland', 'France',
#        'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kuwait',
#        'Latvia', 'Lebanon', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico',
#        'Nepal', 'Netherlands', 'New Zealand', 'Norway', 'Oman', 'Pakistan',
#        'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania',
#        'San Marino', 'Saudi Arabia', 'Singapore', 'Slovenia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Thailand', 'Tunisia',
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Vietnam'],
#       dtype='object', name='Country Name')

# %%
countries_8 = df.groupby(by="Country Name").count() > 56
count_8weeks = countries_8[countries_8["total_cases"]].index

count_8weeks
# Out:
# Index(['Australia', 'Belgium', 'Cambodia', 'Canada', 'China', 'Finland',
#        'France', 'Germany', 'India', 'Italy', 'Japan', 'Malaysia', 'Nepal',
#        'Philippines', 'Singapore', 'Spain', 'Sri Lanka', 'Sweden', 'Thailand',
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Vietnam'],
#       dtype='object', name='Country Name')

# %%
df[df["Country Name"] == "Afghanistan"].iloc[0:14]
# Out:
#    Country Name  total_cases  total_deaths continent  population  Year  \
# 0   Afghanistan            1             0      Asia    38928341  2020
# 1   Afghanistan            1             0      Asia    38928341  2020
# 2   Afghanistan            1             0      Asia    38928341  2020
# 3   Afghanistan            1             0      Asia    38928341  2020
# 4   Afghanistan            1             0      Asia    38928341  2020
# 5   Afghanistan            1             0      Asia    38928341  2020
# 6   Afghanistan            1             0      Asia    38928341  2020
# 7   Afghanistan            4             0      Asia    38928341  2020
# 8   Afghanistan            7             0      Asia    38928341  2020
# 9   Afghanistan           10             0      Asia    38928341  2020
# 10  Afghanistan           16             0      Asia    38928341  2020
# 11  Afghanistan           21             0      Asia    38928341  2020
# ...
