# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hns = pd.read_csv("Health_Nutrition_and_Statistics.csv")
wdi = pd.read_csv("world_development_indicators.csv")

# %%
hns.head()
# Out:
#    Year Year Code    Country Name Country Code  \
# 0  2010    YR2010     Afghanistan          AFG
# 1  2010    YR2010         Albania          ALB
# 2  2010    YR2010         Algeria          DZA
# 3  2010    YR2010  American Samoa          ASM
# 4  2010    YR2010         Andorra          AND
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                               34.3
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Community health workers (per 1,000 people) [SH.MED.CMHW.P3]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
# ...

# %%
for cname in hns:
    if cname == "Year":
        continue
    elif cname == "Country Name":
        continue
    elif cname == "Country Code":
        continue
    elif cname == "Time Code":
        continue
    else:
        hns[cname] = pd.to_numeric(hns[cname], errors='coerce')

# %%
wdi.head()
# Out:
#    Time Time Code Country Name Country Code  \
# 0  2010    YR2010    Argentina          ARG
# 1  2010    YR2010    Australia          AUS
# 2  2010    YR2010       Brazil          BRA
# 3  2010    YR2010        China          CHN
# 4  2010    YR2010       France          FRA
#
#   Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]  \
# 0                                   40.8285418195302
# 1                                   28.1580490459526
# 2                                    36.314913222797
# 3                                    25.468924010163
# 4                                   28.5724568566086
#
#   Community health workers (per 1,000 people) [SH.MED.CMHW.P3]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                               0.81
# 4                                                 ..
#
# ...

# %%
hns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958 entries, 0 to 1957
# Data columns (total 39 columns):
#  #   Column                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                 --------------  -----
#  0   Year                                                                                                                   1955 non-null   object
#  1   Year Code                                                                                                              0 non-null      float64
#  2   Country Name                                                                                                           1953 non-null   object
# ...

# %%
for cname in wdi:
    if cname == "Year":
        continue
    elif cname == "Country Name":
        continue
    elif cname == "Country Code":
        continue
    elif cname == "Time Code":
        continue
    else:
        wdi[cname] = pd.to_numeric(wdi[cname], errors='coerce')

# %%
wdi.head()
# Out:
#      Time Time Code Country Name Country Code  \
# 0  2010.0    YR2010    Argentina          ARG
# 1  2010.0    YR2010    Australia          AUS
# 2  2010.0    YR2010       Brazil          BRA
# 3  2010.0    YR2010        China          CHN
# 4  2010.0    YR2010       France          FRA
#
#    Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]  \
# 0                                          40.828542
# 1                                          28.158049
# 2                                          36.314913
# 3                                          25.468924
# 4                                          28.572457
#
#    Community health workers (per 1,000 people) [SH.MED.CMHW.P3]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               0.81
# 4                                                NaN
#
# ...

# %%
wdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958 entries, 0 to 1957
# Data columns (total 42 columns):
#  #   Column                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                       --------------  -----
#  0   Time                                                                                                                         1953 non-null   float64
#  1   Time Code                                                                                                                    1953 non-null   object
#  2   Country Name                                                                                                                 1953 non-null   object
# ...

# %%
i=0
enough_info_wdi = list()
not_enough_info_wdi = list()
threshold_wdi = 150

for p in wdi:
    i=0
    for j in range(len(wdi.groupby(by="Country Name").count())):
        if p == "Country Name":
            continue
        
        elif wdi.groupby(by="Country Name").any()[p][j] == True:
            i+=1
    if i < threshold_wdi:
        not_enough_info_wdi.append(p)
    else:
        enough_info_wdi.append(p)

# %%
print("How many features in World Development Indicators not have enough data: {} ".format(len(not_enough_info_wdi)))
# Out:
# How many features in World Development Indicators not have enough data: 14

# %%
print("How many features in World Development Indicators have enough data: {} ".format(len(enough_info_wdi)))
# Out:
# How many features in World Development Indicators have enough data: 28

# %%
i=0
enough_info_hns = list()
not_enough_info_hns = list()
threshold_hns = 150

for p in hns:
    i=0
    for j in range(len(hns.groupby(by="Country Name").count())):
        if p == "Country Name":
            continue
        
        elif hns.groupby(by="Country Name").any()[p][j] == True:
            i+=1
    if i < threshold_hns:
        not_enough_info_hns.append(p)
    else:
        enough_info_hns.append(p)

# %%
print("How many features in Health Nutrition and Population not have enough data: {} ".format(len(not_enough_info_hns)))
# Out:
# How many features in Health Nutrition and Population not have enough data: 16

# %%
print("How many features in Health Nutrition and Population have enough data: {} ".format(len(enough_info_hns)))
# Out:
# How many features in Health Nutrition and Population have enough data: 23

# %%
for name in not_enough_info_wdi:
    if name == "Country Name":
        pass
    else:
        del wdi[name]

# %%
for name in not_enough_info_hns:
    if name == "Country Name":
        pass
    elif name == "Year Code":
        pass   
    else:
        del hns[name]

# %%
hns.head()
# Out:
#    Year  Year Code    Country Name Country Code  \
# 0  2010        NaN     Afghanistan          AFG
# 1  2010        NaN         Albania          ALB
# 2  2010        NaN         Algeria          DZA
# 3  2010        NaN  American Samoa          ASM
# 4  2010        NaN         Andorra          AND
#
#    Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                               34.3
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]  \
# 0                                          45.587750
# 1                                         203.208589
# 2                                         228.399544
# 3                                                NaN
# ...

# %%
wdi.head()
# Out:
#      Time Time Code Country Name Country Code  \
# 0  2010.0    YR2010    Argentina          ARG
# 1  2010.0    YR2010    Australia          AUS
# 2  2010.0    YR2010       Brazil          BRA
# 3  2010.0    YR2010        China          CHN
# 4  2010.0    YR2010       France          FRA
#
#    Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]  \
# 0                                          40.828542
# 1                                          28.158049
# 2                                          36.314913
# 3                                          25.468924
# 4                                          28.572457
#
#    Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]  \
# 0                                           8.613662
# 1                                           8.430844
# 2                                           7.949067
# 3                                           4.207991
# 4                                          11.239024
#
# ...

# %%
samefeatures = list()
for wdix in wdi:
    for hnsx in hns:
        if wdix == hnsx:
            samefeatures.append(wdix)
            
samefeatures
# Out:
# ['Country Name',
#  'Country Code',
#  'Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]',
#  'Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]',
#  'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]']

# %%
del samefeatures[1]
del samefeatures[0]

samefeatures
# Out:
# ['Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]',
#  'Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]',
#  'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]']

# %%
for wdiname in wdi:
    for same in samefeatures:
        if wdiname==same:
            del wdi[wdiname]

# %% [markdown]
# Now there is no common feature between hns and wdi

# %%
pd.to_numeric(hns["Year"],errors="coerce")
# Out:
# 0       2010.0
# 1       2010.0
# 2       2010.0
# 3       2010.0
# 4       2010.0
#          ...
# 1953       NaN
# 1954       NaN
# 1955       NaN
# 1956       NaN
# 1957       NaN
# Name: Year, Length: 1958, dtype: float64

# %%
for i in range(len(hns)):
    if (hns[hns.index == i]["Year"] == "NaN").bool():
        del hns[hns.index == i]

# %%
hns = hns[hns["Country Code"].isnull() == False]

# %%
wdi = wdi[wdi["Country Code"].isnull() == False]

# %%
del hns["Year Code"]

# %%
hns
# Out:
#       Year           Country Name Country Code  \
# 0     2010            Afghanistan          AFG
# 1     2010                Albania          ALB
# 2     2010                Algeria          DZA
# 3     2010         American Samoa          ASM
# 4     2010                Andorra          AND
# ...    ...                    ...          ...
# 1948  2018  Virgin Islands (U.S.)          VIR
# 1949  2018     West Bank and Gaza          PSE
# 1950  2018            Yemen, Rep.          YEM
# 1951  2018                 Zambia          ZMB
# 1952  2018               Zimbabwe          ZWE
#
#       Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                  34.3
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...

# %%
hns = hns.sort_values(by=["Country Name","Year"])
hns.reset_index(drop=True,inplace=True)

# %%
wdi = wdi.sort_values(by=["Country Name","Time"])
wdi.reset_index(drop=True,inplace=True)

# %%
wdi
# Out:
#         Time Time Code Country Name Country Code  \
# 0     2010.0    YR2010  Afghanistan          AFG
# 1     2011.0    YR2011  Afghanistan          AFG
# 2     2012.0    YR2012  Afghanistan          AFG
# 3     2013.0    YR2013  Afghanistan          AFG
# 4     2014.0    YR2014  Afghanistan          AFG
# ...      ...       ...          ...          ...
# 1948  2014.0    YR2014     Zimbabwe          ZWE
# 1949  2015.0    YR2015     Zimbabwe          ZWE
# 1950  2016.0    YR2016     Zimbabwe          ZWE
# 1951  2017.0    YR2017     Zimbabwe          ZWE
# 1952  2018.0    YR2018     Zimbabwe          ZWE
#
#       Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]  \
# 0                                             97.341930
# 1                                             95.510252
# 2                                             93.202852
# 3                                             90.611139
# 4                                             87.926203
# ...

# %%
for countri in range(0,1953,9):
    for yeari in range(1,9):
        for x in wdi:
            flag = pd.isnull(wdi.loc[(countri + yeari) ,x])
            if flag:
                wdi.loc[(countri + yeari) ,x] = wdi.loc[(countri + yeari-1) ,x]

# %%
for countri in range(0,1953,9):
    for yeari in range(1,9):
        for x in hns:
            flag = pd.isnull(hns.loc[(countri + yeari) ,x])
            if flag:
                hns.loc[(countri + yeari) ,x] = hns.loc[(countri + yeari-1) ,x]

# %%
hns.head(20)
# Out:
#     Year Country Name Country Code  \
# 0   2010  Afghanistan          AFG
# 1   2011  Afghanistan          AFG
# 2   2012  Afghanistan          AFG
# 3   2013  Afghanistan          AFG
# 4   2014  Afghanistan          AFG
# 5   2015  Afghanistan          AFG
# 6   2016  Afghanistan          AFG
# 7   2017  Afghanistan          AFG
# 8   2018  Afghanistan          AFG
# 9   2010      Albania          ALB
# 10  2011      Albania          ALB
# 11  2012      Albania          ALB
# 12  2013      Albania          ALB
# 13  2014      Albania          ALB
# 14  2015      Albania          ALB
# 15  2016      Albania          ALB
# 16  2017      Albania          ALB
# 17  2018      Albania          ALB
# 18  2010      Algeria          DZA
# 19  2011      Algeria          DZA
#
#     Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                34.3
# 1                                                38.6
# ...

# %%
wdi.head(20)
# Out:
#       Time Time Code Country Name Country Code  \
# 0   2010.0    YR2010  Afghanistan          AFG
# 1   2011.0    YR2011  Afghanistan          AFG
# 2   2012.0    YR2012  Afghanistan          AFG
# 3   2013.0    YR2013  Afghanistan          AFG
# 4   2014.0    YR2014  Afghanistan          AFG
# 5   2015.0    YR2015  Afghanistan          AFG
# 6   2016.0    YR2016  Afghanistan          AFG
# 7   2017.0    YR2017  Afghanistan          AFG
# 8   2018.0    YR2018  Afghanistan          AFG
# 9   2010.0    YR2010      Albania          ALB
# 10  2011.0    YR2011      Albania          ALB
# 11  2012.0    YR2012      Albania          ALB
# 12  2013.0    YR2013      Albania          ALB
# 13  2014.0    YR2014      Albania          ALB
# 14  2015.0    YR2015      Albania          ALB
# 15  2016.0    YR2016      Albania          ALB
# 16  2017.0    YR2017      Albania          ALB
# 17  2018.0    YR2018      Albania          ALB
# 18  2010.0    YR2010      Algeria          DZA
# ...

# %% [markdown]
# Now as our 2018 Values have the newest data available in them we do not need Year's datas other than 2018.

# %%
wdi = wdi[wdi["Time"] == 2018]
hns = hns[hns["Year"] == "2018"]

# %%
wdi.reset_index(drop=True,inplace=True)
wdi
# Out:
#        Time Time Code           Country Name Country Code  \
# 0    2018.0    YR2018            Afghanistan          AFG
# 1    2018.0    YR2018                Albania          ALB
# 2    2018.0    YR2018                Algeria          DZA
# 3    2018.0    YR2018         American Samoa          ASM
# 4    2018.0    YR2018                Andorra          AND
# ..      ...       ...                    ...          ...
# 212  2018.0    YR2018  Virgin Islands (U.S.)          VIR
# 213  2018.0    YR2018     West Bank and Gaza          PSE
# 214  2018.0    YR2018            Yemen, Rep.          YEM
# 215  2018.0    YR2018                 Zambia          ZMB
# 216  2018.0    YR2018               Zimbabwe          ZWE
#
#      Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]  \
# 0                                            79.319383
# 1                                            25.768823
# 2                                            47.486590
# ...

# %%
hns.reset_index(drop=True,inplace=True)
hns
# Out:
#      Year           Country Name Country Code  \
# 0    2018            Afghanistan          AFG
# 1    2018                Albania          ALB
# 2    2018                Algeria          DZA
# 3    2018         American Samoa          ASM
# 4    2018                Andorra          AND
# ..    ...                    ...          ...
# 212  2018  Virgin Islands (U.S.)          VIR
# 213  2018     West Bank and Gaza          PSE
# 214  2018            Yemen, Rep.          YEM
# 215  2018                 Zambia          ZMB
# 216  2018               Zimbabwe          ZWE
#
#      Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                 50.5
# 1                                                 99.8
# 2                                                 96.6
# 3                                                  NaN
# 4                                                  NaN
# ...

# %% [markdown]
# Now I will save them in order to merge them into one with my main data.

# %%
hns.to_csv("hns.csv")
wdi.to_csv("wdi.csv")
