# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_cleaned_thresholded.csv")
df
# Out:
#       Unnamed: 0     location  new_cases  new_deaths  total_cases  \
# 0              0  Afghanistan          1           0            1
# 1              1  Afghanistan          0           0            1
# 2              2  Afghanistan          0           0            1
# 3              3  Afghanistan          0           0            1
# 4              4  Afghanistan          0           0            1
# ...          ...          ...        ...         ...          ...
# 3244        3244      Vietnam          6           0          235
# 3245        3245      Vietnam          4           0          239
# 3246        3246      Vietnam          0           0          239
# 3247        3247      Vietnam          1           0          240
# 3248        3248      Vietnam          1           0          241
#
#       total_deaths continent  population
# 0                0      Asia    38928341
# 1                0      Asia    38928341
# 2                0      Asia    38928341
# ...

# %%
print("Max data:{}".format(max(df.groupby(by="location")["new_cases"].count())))
print("Min data:{}".format(min(df.groupby(by="location")["new_cases"].count())))
# Out:
# Max data:98
# Min data:31

# %%
df.groupby(by="location")["new_cases"].count().sort_values()
plt.figure(figsize=(15,15))
plt.scatter(df.groupby(by="location")["new_cases"].count().sort_values(),df.groupby(by="location")["new_cases"].count().sort_values().index)
plt.axvline(55,color="red")
plt.axvline(80,color="red")
plt.show()

# %%
lower_group = df.groupby(by="location")["new_cases"].count() < 50
higher_group =  df.groupby(by="location")["new_cases"].count() > 50

# %%
lower_group = lower_group[lower_group == True]
lower_group = lower_group.index

higher_group = higher_group[higher_group == True]
higher_group = higher_group.index

# %%
df.groupby(by="location")["new_cases"].count() < 50
# Out:
# location
# Afghanistan              True
# Algeria                  True
# Argentina                True
# Australia               False
# Austria                  True
#                         ...
# Thailand                False
# United Arab Emirates    False
# United Kingdom          False
# United States           False
# Vietnam                 False
# Name: new_cases, Length: 65, dtype: bool
