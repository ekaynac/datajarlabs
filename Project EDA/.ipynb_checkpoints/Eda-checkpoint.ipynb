# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data12-4-20.csv")
df
# Out:
#       Unnamed: 0 Country Name  total_cases  total_deaths continent  \
# 0              0  Afghanistan            1             0      Asia
# 1              1  Afghanistan            1             0      Asia
# 2              2  Afghanistan            1             0      Asia
# 3              3  Afghanistan            1             0      Asia
# 4              4  Afghanistan            1             0      Asia
# ...          ...          ...          ...           ...       ...
# 5095        5095     Zimbabwe            8             1    Africa
# 5096        5096     Zimbabwe            8             1    Africa
# 5097        5097     Zimbabwe            9             1    Africa
# 5098        5098     Zimbabwe            9             1    Africa
# 5099        5099     Zimbabwe            9             1    Africa
#
#       population  Year  \
# 0       38928341  2020
# 1       38928341  2020
# 2       38928341  2020
# 3       38928341  2020
# 4       38928341  2020
# ...          ...   ...
# 5095    14862927  2020
# 5096    14862927  2020
# 5097    14862927  2020
# 5098    14862927  2020
# 5099    14862927  2020
#
#       Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                  50.5
# 1                                                  50.5
# 2                                                  50.5
# 3                                                  50.5
# 4                                                  50.5
# ...                                                 ...
# 5095                                               78.1
# 5096                                               78.1
# 5097                                               78.1
# 5098                                               78.1
# 5099                                               78.1
#
#       Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]  \
# 0                                             57.248760
# 1                                             57.248760
# 2                                             57.248760
# 3                                             57.248760
# 4                                             57.248760
# ...                                                 ...
# 5095                                          93.942225
# 5096                                          93.942225
# 5097                                          93.942225
# 5098                                          93.942225
# 5099                                          93.942225
#
#       Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]  \
# 0                                            162.781158
# 1                                            162.781158
# 2                                            162.781158
# 3                                            162.781158
# 4                                            162.781158
# ...                                                 ...
# 5095                                         185.048282
# 5096                                         185.048282
# 5097                                         185.048282
# 5098                                         185.048282
# 5099                                         185.048282
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5095  ...
# 5096  ...
# 5097  ...
# 5098  ...
# 5099  ...
#
#       Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]  \
# 0                                             42.331198
# 1                                             42.331198
# 2                                             42.331198
# 3                                             42.331198
# 4                                             42.331198
# ...                                                 ...
# 5095                                          32.576344
# 5096                                          32.576344
# 5097                                          32.576344
# 5098                                          32.576344
# 5099                                          32.576344
#
#       Population in largest city [EN.URB.LCTY]  \
# 0                                    4011770.0
# 1                                    4011770.0
# 2                                    4011770.0
# 3                                    4011770.0
# 4                                    4011770.0
# ...                                        ...
# 5095                                 1515016.0
# 5096                                 1515016.0
# 5097                                 1515016.0
# 5098                                 1515016.0
# 5099                                 1515016.0
#
#       Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]  \
# 0                                              4.758273
# 1                                              4.758273
# 2                                              4.758273
# 3                                              4.758273
# 4                                              4.758273
# ...                                                 ...
# 5095                                           5.377887
# 5096                                           5.377887
# 5097                                           5.377887
# 5098                                           5.377887
# 5099                                           5.377887
#
#       Age dependency ratio (% of working-age population) [SP.POP.DPND]  \
# 0                                             84.077656
# 1                                             84.077656
# 2                                             84.077656
# 3                                             84.077656
# 4                                             84.077656
# ...                                                 ...
# 5095                                          82.951116
# 5096                                          82.951116
# 5097                                          82.951116
# 5098                                          82.951116
# 5099                                          82.951116
#
#       Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]  \
# 0                                            466.079081
# 1                                            466.079081
# 2                                            466.079081
# 3                                            466.079081
# 4                                            466.079081
# ...                                                 ...
# 5095                                        1142.940418
# 5096                                        1142.940418
# 5097                                        1142.940418
# 5098                                        1142.940418
# 5099                                        1142.940418
#
#       Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]  \
# 0                                              32.27117
# 1                                              32.27117
# 2                                              32.27117
# 3                                              32.27117
# 4                                              32.27117
# ...                                                 ...
# 5095                                           11.71069
# 5096                                           11.71069
# 5097                                           11.71069
# 5098                                           11.71069
# 5099                                           11.71069
#
#       Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]  2 weeks  \
# 0                                                125.41            True
# 1                                                125.41            True
# 2                                                125.41            True
# 3                                                125.41            True
# 4                                                125.41            True
# ...                                                 ...             ...
# 5095                                              88.75            True
# 5096                                              88.75            True
# 5097                                              88.75            True
# 5098                                              88.75            True
# 5099                                              88.75            True
#
#       4 weeks  +8 weeks
# 0        True     False
# 1        True     False
# 2        True     False
# 3        True     False
# 4        True     False
# ...       ...       ...
# 5095    False     False
# 5096    False     False
# 5097    False     False
# 5098    False     False
# 5099    False     False
#
# [5100 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 55 columns):
#  #   Column                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                 --------------  -----
#  0   Unnamed: 0                                                                                                             5100 non-null   int64
#  1   Country Name                                                                                                           5100 non-null   object
#  2   total_cases                                                                                                            5100 non-null   int64
#  3   total_deaths                                                                                                           5100 non-null   int64
#  4   continent                                                                                                              5100 non-null   object
#  5   population                                                                                                             5100 non-null   int64
#  6   Year                                                                                                                   5100 non-null   int64
#  7   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                                                  4291 non-null   float64
#  8   Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]                                                4871 non-null   float64
#  9   Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]                               4871 non-null   float64
#  10  Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]                                                   5025 non-null   float64
#  11  Life expectancy at birth, total (years) [SP.DYN.LE00.IN]                                                               5000 non-null   float64
#  12  Labor force, total [SL.TLF.TOTL.IN]                                                                                    4788 non-null   float64
#  13  Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]                                            3581 non-null   float64
#  14  Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]                                                3563 non-null   float64
#  15  Net migration [SM.POP.NETM]                                                                                            4859 non-null   float64
#  16  People using at least basic drinking water services (% of population) [SH.H2O.BASW.ZS]                                 5078 non-null   float64
#  17  People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]                 4320 non-null   float64
#  18  People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]                 4474 non-null   float64
#  19  People using at least basic sanitation services (% of population) [SH.STA.BASS.ZS]                                     5061 non-null   float64
#  20  People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]                     4247 non-null   float64
#  21  People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]                    4401 non-null   float64
#  22  Rural population (% of total population) [SP.RUR.TOTL.ZS]                                                              5078 non-null   float64
#  23  School enrollment, primary (% gross) [SE.PRM.ENRR]                                                                     4669 non-null   float64
#  24  School enrollment, secondary (% gross) [SE.SEC.ENRR]                                                                   4379 non-null   float64
#  25  School enrollment, tertiary (% gross) [SE.TER.ENRR]                                                                    4378 non-null   float64
#  26  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]  4828 non-null   float64
#  27  Urban population (% of total population) [SP.URB.TOTL.IN.ZS]                                                           5078 non-null   float64
#  28  Time                                                                                                                   5100 non-null   float64
#  29  Time Code                                                                                                              5100 non-null   object
#  30  Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]                                             4859 non-null   float64
#  31  Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                              4822 non-null   float64
#  32  Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                          4851 non-null   float64
#  33  Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]               4851 non-null   float64
#  34  Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]                   4822 non-null   float64
#  35  Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                            4851 non-null   float64
#  36  Domestic general government health expenditure per capita, PPP (current international $) [SH.XPD.GHED.PP.CD]           4851 non-null   float64
#  37  Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                              4822 non-null   float64
#  38  Domestic private health expenditure per capita (current US$) [SH.XPD.PVTD.PC.CD]                                       4822 non-null   float64
#  39  Domestic private health expenditure per capita, PPP (current international $) [SH.XPD.PVTD.PP.CD]                      4822 non-null   float64
#  40  External health expenditure per capita, PPP (current international $) [SH.XPD.EHEX.PP.CD]                              4851 non-null   float64
#  41  External health expenditure per capita (current US$) [SH.XPD.EHEX.PC.CD]                                               4851 non-null   float64
#  42  Population density (people per sq. km of land area) [EN.POP.DNST]                                                      5076 non-null   float64
#  43  Land area (sq. km) [AG.LND.TOTL.K2]                                                                                    5076 non-null   float64
#  44  Urban land area (sq. km) [AG.LND.TOTL.UR.K2]                                                                           4420 non-null   float64
#  45  Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]                                             4410 non-null   float64
#  46  Population in largest city [EN.URB.LCTY]                                                                               4410 non-null   float64
#  47  Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]                                               4859 non-null   float64
#  48  Age dependency ratio (% of working-age population) [SP.POP.DPND]                                                       4859 non-null   float64
#  49  Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]                                              4707 non-null   float64
#  50  Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]                                                            4689 non-null   float64
#  51  Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]                                                               4940 non-null   float64
#  52  2 weeks                                                                                                                5100 non-null   bool
#  53  4 weeks                                                                                                                5100 non-null   bool
#  54  +8 weeks                                                                                                               5100 non-null   bool
# dtypes: bool(3), float64(44), int64(5), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# Let us see the percentage of missing data.

# %%
missing_percentage = df.isnull().sum()*100/df.shape[0]

missing_percentage[missing_percentage>0]
# Out:
# Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                                                    15.862745
# Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]                                                   4.490196
# Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]                                  4.490196
# Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]                                                      1.470588
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN]                                                                  1.960784
# Labor force, total [SL.TLF.TOTL.IN]                                                                                       6.117647
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]                                              29.784314
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]                                                  30.137255
# Net migration [SM.POP.NETM]                                                                                               4.725490
# People using at least basic drinking water services (% of population) [SH.H2O.BASW.ZS]                                    0.431373
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]                   15.294118
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]                   12.274510
# People using at least basic sanitation services (% of population) [SH.STA.BASS.ZS]                                        0.764706
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]                       16.725490
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]                      13.705882
# Rural population (% of total population) [SP.RUR.TOTL.ZS]                                                                 0.431373
# School enrollment, primary (% gross) [SE.PRM.ENRR]                                                                        8.450980
# School enrollment, secondary (% gross) [SE.SEC.ENRR]                                                                     14.137255
# School enrollment, tertiary (% gross) [SE.TER.ENRR]                                                                      14.156863
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]     5.333333
# Urban population (% of total population) [SP.URB.TOTL.IN.ZS]                                                              0.431373
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]                                                4.725490
# Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                                 5.450980
# Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                             4.882353
# Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]                  4.882353
# Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]                      5.450980
# Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                               4.882353
# Domestic general government health expenditure per capita, PPP (current international $) [SH.XPD.GHED.PP.CD]              4.882353
# Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                                 5.450980
# Domestic private health expenditure per capita (current US$) [SH.XPD.PVTD.PC.CD]                                          5.450980
# Domestic private health expenditure per capita, PPP (current international $) [SH.XPD.PVTD.PP.CD]                         5.450980
# External health expenditure per capita, PPP (current international $) [SH.XPD.EHEX.PP.CD]                                 4.882353
# External health expenditure per capita (current US$) [SH.XPD.EHEX.PC.CD]                                                  4.882353
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                         0.470588
# Land area (sq. km) [AG.LND.TOTL.K2]                                                                                       0.470588
# Urban land area (sq. km) [AG.LND.TOTL.UR.K2]                                                                             13.333333
# Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]                                               13.529412
# Population in largest city [EN.URB.LCTY]                                                                                 13.529412
# Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]                                                  4.725490
# Age dependency ratio (% of working-age population) [SP.POP.DPND]                                                          4.725490
# Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]                                                 7.705882
# Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]                                                               8.058824
# Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]                                                                  3.137255
# dtype: float64

# %% [markdown]
# It's easy to find some of the missing information manually. For example, seems like we have a missing "Land Area" information for only one country. I will check our features and will fill the missing data manually from other resources if I can.

# %%
dfcountrycheck = df.groupby(by = "Country Name").sum()
dfcountrycheck
# Out:
#               Unnamed: 0  total_cases  total_deaths  population    Year  \
# Country Name
# Afghanistan          496         2294            45  1245706912   64640
# Albania             1334         3773           181    83456200   58580
# Algeria             2826         9334           761  1578637548   72720
# Andorra             2604         5028           116     1854360   48480
# Angola              2056           90            16   525860288   32320
# ...                  ...          ...           ...         ...     ...
# Uruguay           114080         4883            24    79895721   46460
# Uzbekistan        109615         2356            16   736322378   44440
# Vietnam           351995         4243             0  6813700810  141400
# Zambia             96387          378             4   349295164   38380
# Zimbabwe           86547           92            14   252669759   34340
#
#               Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# Country Name
# Afghanistan                                              1616.0
# Albania                                                  2894.2
# Algeria                                                  3477.6
# Andorra                                                     0.0
# Angola                                                    793.6
# ...                                                         ...
# Uruguay                                                  2297.7
# Uzbekistan                                               2200.0
# Vietnam                                                  6566.0
# Zambia                                                   1202.7
# Zimbabwe                                                 1327.7
#
#               Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]  \
# Country Name
# Afghanistan                                         1831.960335
# Albania                                             7874.748235
# Algeria                                             9374.852856
# Andorra                                            92033.533954
# Angola                                              1523.532777
# ...                                                         ...
# Uruguay                                            31719.266820
# Uzbekistan                                          2972.445487
# Vietnam                                             8598.882176
# Zambia                                              1074.339460
# Zimbabwe                                            1597.017827
#
#               Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]  \
# Country Name
# Afghanistan                                         5208.997062
# Albania                                            22030.342542
# Algeria                                            35933.535140
# Andorra                                           119488.958438
# Angola                                              2973.126410
# ...                                                         ...
# Uruguay                                            45054.705025
# Uzbekistan                                          9171.887595
# Vietnam                                            24939.575832
# Zambia                                              3328.388690
# Zimbabwe                                            3145.820792
#
#               Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]  \
# Country Name
# Afghanistan                                               275.2
# Albania                                                   130.5
# Algeria                                                   306.0
# Andorra                                                   158.4
# Angola                                                     56.0
# ...                                                         ...
# Uruguay                                                   131.1
# Uzbekistan                                                114.4
# Vietnam                                                   245.0
# Zambia                                                     76.0
# Zimbabwe                                                   69.7
#
#               Life expectancy at birth, total (years) [SP.DYN.LE00.IN]  ...  \
# Country Name                                                            ...
# Afghanistan                                            2052.160         ...
# Albania                                                2271.657         ...
# Algeria                                                2753.964         ...
# Andorra                                                   0.000         ...
# Angola                                                  966.064         ...
# ...                                                         ...         ...
# Uruguay                                                1785.536         ...
# Uzbekistan                                             1570.536         ...
# Vietnam                                                5266.870         ...
# Zambia                                                 1197.817         ...
# Zimbabwe                                               1033.804         ...
#
#               Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]  \
# Country Name
# Afghanistan                                         1354.598348
# Albania                                              797.685384
# Algeria                                              316.163157
# Andorra                                                0.000000
# Angola                                               616.244764
# ...                                                         ...
# Uruguay                                             1214.915877
# Uzbekistan                                           325.858601
# Vietnam                                             1661.487634
# Zambia                                               634.997748
# Zimbabwe                                             553.797856
#
#               Population in largest city [EN.URB.LCTY]  \
# Country Name
# Afghanistan                                128376640.0
# Albania                                     13791733.0
# Algeria                                     96967512.0
# Andorra                                            0.0
# Angola                                     124387200.0
# ...                                                ...
# Uruguay                                     39950747.0
# Uzbekistan                                  54207318.0
# Vietnam                                    570175270.0
# Zambia                                      47953036.0
# Zimbabwe                                    25755272.0
#
#               Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]  \
# Country Name
# Afghanistan                                          152.264730
# Albania                                              581.195211
# Algeria                                              360.771916
# Andorra                                                0.000000
# Angola                                                69.567755
# ...                                                         ...
# Uruguay                                              527.635646
# Uzbekistan                                           145.334253
# Vietnam                                              732.180176
# Zambia                                                75.322304
# Zimbabwe                                              91.424077
#
#               Age dependency ratio (% of working-age population) [SP.POP.DPND]  \
# Country Name
# Afghanistan                                         2690.484994
# Albania                                             1328.491084
# Algeria                                             2070.289168
# Andorra                                                0.000000
# Angola                                              1538.811847
# ...                                                         ...
# Uruguay                                             1261.612115
# Uzbekistan                                          1088.745750
# Vietnam                                             3064.362338
# Zambia                                              1687.330040
# Zimbabwe                                            1410.168973
#
#               Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]  \
# Country Name
# Afghanistan                                        14914.530606
# Albania                                           119049.364933
# Algeria                                           117276.367462
# Andorra                                                0.000000
# Angola                                             34372.367503
# ...                                                         ...
# Uruguay                                           326262.036246
# Uzbekistan                                         30206.321374
# Vietnam                                           136403.459722
# Zambia                                             21458.474123
# Zimbabwe                                           19429.987103
#
#               Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]  \
# Country Name
# Afghanistan                                         1032.677448
# Albania                                              392.837204
# Algeria                                              728.682073
# Andorra                                              532.813405
# Angola                                               317.201676
# ...                                                         ...
# Uruguay                                              335.210353
# Uzbekistan                                           207.658198
# Vietnam                                              561.270881
# Zambia                                               100.257511
# Zimbabwe                                             199.081734
#
#               Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]  \
# Country Name
# Afghanistan                                             4013.12
# Albania                                                 4376.97
# Algeria                                                 5458.32
# Andorra                                                    0.00
# Angola                                                  3085.60
# ...                                                         ...
# Uruguay                                                 2682.95
# Uzbekistan                                              3455.76
# Vietnam                                                 9532.60
# Zambia                                                  3415.63
# Zimbabwe                                                1508.75
#
#               2 weeks  4 weeks  +8 weeks
# Country Name
# Afghanistan      32.0     32.0       0.0
# Albania          29.0     29.0       0.0
# Algeria          36.0     36.0       0.0
# Andorra          24.0      0.0       0.0
# Angola           16.0      0.0       0.0
# ...               ...      ...       ...
# Uruguay          23.0      0.0       0.0
# Uzbekistan       22.0      0.0       0.0
# Vietnam          70.0     70.0      70.0
# Zambia           19.0      0.0       0.0
# Zimbabwe         17.0      0.0       0.0
#
# [155 rows x 52 columns]

# %% [markdown]
# Since our features are not changing in same country I grouped them by "Country Name". If a value of a feature is zero for a country ,this means we have missing data for the country on the feature. W

# %%
missing_percentage = df.isnull().sum()*100/df.shape[0]

missing_percentage[missing_percentage>0]
# Out:
# Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                                                    15.862745
# Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]                                                   4.490196
# Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]                                  4.490196
# Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]                                                      1.470588
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN]                                                                  1.960784
# Labor force, total [SL.TLF.TOTL.IN]                                                                                       6.117647
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]                                              29.784314
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]                                                  30.137255
# Net migration [SM.POP.NETM]                                                                                               4.725490
# People using at least basic drinking water services (% of population) [SH.H2O.BASW.ZS]                                    0.431373
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]                   15.294118
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]                   12.274510
# People using at least basic sanitation services (% of population) [SH.STA.BASS.ZS]                                        0.764706
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]                       16.725490
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]                      13.705882
# Rural population (% of total population) [SP.RUR.TOTL.ZS]                                                                 0.431373
# School enrollment, primary (% gross) [SE.PRM.ENRR]                                                                        8.450980
# School enrollment, secondary (% gross) [SE.SEC.ENRR]                                                                     14.137255
# School enrollment, tertiary (% gross) [SE.TER.ENRR]                                                                      14.156863
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]     5.333333
# Urban population (% of total population) [SP.URB.TOTL.IN.ZS]                                                              0.431373
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]                                                4.725490
# Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                                 5.450980
# Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                             4.882353
# Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]                  4.882353
# Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]                      5.450980
# Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                               4.882353
# Domestic general government health expenditure per capita, PPP (current international $) [SH.XPD.GHED.PP.CD]              4.882353
# Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                                 5.450980
# Domestic private health expenditure per capita (current US$) [SH.XPD.PVTD.PC.CD]                                          5.450980
# Domestic private health expenditure per capita, PPP (current international $) [SH.XPD.PVTD.PP.CD]                         5.450980
# External health expenditure per capita, PPP (current international $) [SH.XPD.EHEX.PP.CD]                                 4.882353
# External health expenditure per capita (current US$) [SH.XPD.EHEX.PC.CD]                                                  4.882353
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                         0.470588
# Land area (sq. km) [AG.LND.TOTL.K2]                                                                                       0.470588
# Urban land area (sq. km) [AG.LND.TOTL.UR.K2]                                                                             13.333333
# Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]                                               13.529412
# Population in largest city [EN.URB.LCTY]                                                                                 13.529412
# Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]                                                  4.725490
# Age dependency ratio (% of working-age population) [SP.POP.DPND]                                                          4.725490
# Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]                                                 7.705882
# Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]                                                               8.058824
# Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]                                                                  3.137255
# dtype: float64

# %%
features_can_found_manually = ["Population in largest city [EN.URB.LCTY]",
                               "Life expectancy at birth, total (years) [SP.DYN.LE00.IN]",
                               "Labor force, total [SL.TLF.TOTL.IN]",
                               "Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]",
                               "Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]",
                               "Net migration [SM.POP.NETM]",
                               "People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]",
                               "People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]",
                               "People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]",
                               "People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]",
                               "Rural population (% of total population) [SP.RUR.TOTL.ZS]",
                               "School enrollment, primary (% gross) [SE.PRM.ENRR]",
                               "School enrollment, secondary (% gross) [SE.SEC.ENRR]",
                               "School enrollment, tertiary (% gross) [SE.TER.ENRR]",
                               "Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]",
                               "Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]"]

# %%
for feature in features_can_found_manually:
    for country in dfcountrycheck.index:
        if dfcountrycheck.loc[country,feature] == 0:
            print("{} is missing for {}".format(feature,country))
# Out:
# Population in largest city [EN.URB.LCTY] is missing for Andorra
# Population in largest city [EN.URB.LCTY] is missing for Antigua and Barbuda
# Population in largest city [EN.URB.LCTY] is missing for Aruba
# Population in largest city [EN.URB.LCTY] is missing for Barbados
# Population in largest city [EN.URB.LCTY] is missing for Bermuda
# Population in largest city [EN.URB.LCTY] is missing for Bhutan
# Population in largest city [EN.URB.LCTY] is missing for Cayman Islands
# Population in largest city [EN.URB.LCTY] is missing for Cyprus
# Population in largest city [EN.URB.LCTY] is missing for Dominica
# Population in largest city [EN.URB.LCTY] is missing for Fiji
# Population in largest city [EN.URB.LCTY] is missing for French Polynesia
# Population in largest city [EN.URB.LCTY] is missing for Gibraltar
# Population in largest city [EN.URB.LCTY] is missing for Greenland
# Population in largest city [EN.URB.LCTY] is missing for Grenada
# Population in largest city [EN.URB.LCTY] is missing for Guam
# Population in largest city [EN.URB.LCTY] is missing for Guyana
# Population in largest city [EN.URB.LCTY] is missing for Iceland
# Population in largest city [EN.URB.LCTY] is missing for Isle of Man
# Population in largest city [EN.URB.LCTY] is missing for Kosovo
# Population in largest city [EN.URB.LCTY] is missing for Liechtenstein
# Population in largest city [EN.URB.LCTY] is missing for Luxembourg
# Population in largest city [EN.URB.LCTY] is missing for Maldives
# Population in largest city [EN.URB.LCTY] is missing for Malta
# Population in largest city [EN.URB.LCTY] is missing for Mauritius
# Population in largest city [EN.URB.LCTY] is missing for Monaco
# Population in largest city [EN.URB.LCTY] is missing for Montenegro
# Population in largest city [EN.URB.LCTY] is missing for New Caledonia
# Population in largest city [EN.URB.LCTY] is missing for San Marino
# Population in largest city [EN.URB.LCTY] is missing for Seychelles
# Population in largest city [EN.URB.LCTY] is missing for Slovenia
# Population in largest city [EN.URB.LCTY] is missing for Suriname
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Andorra
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Dominica
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Gibraltar
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Isle of Man
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Monaco
# Labor force, total [SL.TLF.TOTL.IN] is missing for Andorra
# Labor force, total [SL.TLF.TOTL.IN] is missing for Antigua and Barbuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Aruba
# Labor force, total [SL.TLF.TOTL.IN] is missing for Bermuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Cayman Islands
# Labor force, total [SL.TLF.TOTL.IN] is missing for Dominica
# Labor force, total [SL.TLF.TOTL.IN] is missing for Gibraltar
# Labor force, total [SL.TLF.TOTL.IN] is missing for Greenland
# Labor force, total [SL.TLF.TOTL.IN] is missing for Grenada
# Labor force, total [SL.TLF.TOTL.IN] is missing for Isle of Man
# Labor force, total [SL.TLF.TOTL.IN] is missing for Kosovo
# Labor force, total [SL.TLF.TOTL.IN] is missing for Liechtenstein
# Labor force, total [SL.TLF.TOTL.IN] is missing for Monaco
# Labor force, total [SL.TLF.TOTL.IN] is missing for San Marino
# Labor force, total [SL.TLF.TOTL.IN] is missing for Seychelles
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Andorra
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Australia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Austria
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Belgium
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Bermuda
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Canada
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Cayman Islands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Czech Republic
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Denmark
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Djibouti
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Dominica
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Finland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for France
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for French Polynesia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Germany
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Gibraltar
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Greenland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Guam
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Iceland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Ireland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Isle of Man
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Israel
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Japan
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Kosovo
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Liechtenstein
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Luxembourg
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Monaco
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Namibia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Netherlands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for New Zealand
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Norway
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Poland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Somalia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Sweden
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Switzerland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Arab Emirates
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Kingdom
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United States
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Andorra
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Antigua and Barbuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Australia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Austria
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Belgium
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Bermuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Canada
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Cayman Islands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Czech Republic
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Denmark
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Djibouti
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Dominica
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Finland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for France
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for French Polynesia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Germany
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Gibraltar
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Greenland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Guam
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Iceland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Ireland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Isle of Man
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Israel
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Japan
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Kosovo
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Liechtenstein
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Luxembourg
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Monaco
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Namibia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Netherlands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for New Zealand
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Norway
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Poland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Somalia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Sweden
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Switzerland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Arab Emirates
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Kingdom
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United States
# Net migration [SM.POP.NETM] is missing for Andorra
# Net migration [SM.POP.NETM] is missing for Antigua and Barbuda
# Net migration [SM.POP.NETM] is missing for Bermuda
# Net migration [SM.POP.NETM] is missing for Cayman Islands
# Net migration [SM.POP.NETM] is missing for Dominica
# Net migration [SM.POP.NETM] is missing for Gibraltar
# Net migration [SM.POP.NETM] is missing for Greenland
# Net migration [SM.POP.NETM] is missing for Isle of Man
# Net migration [SM.POP.NETM] is missing for Kosovo
# Net migration [SM.POP.NETM] is missing for Liechtenstein
# Net migration [SM.POP.NETM] is missing for Mauritius
# Net migration [SM.POP.NETM] is missing for Monaco
# Net migration [SM.POP.NETM] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Aruba
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bahrain
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Barbados
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bermuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Cayman Islands
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Dominica
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for French Polynesia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Gibraltar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Grenada
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Guam
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Isle of Man
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Japan
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kosovo
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kuwait
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Lebanon
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Monaco
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for New Caledonia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Qatar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Seychelles
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Singapore
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for United Arab Emirates
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Aruba
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Bahrain
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Barbados
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Dominica
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for French Polynesia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Grenada
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Guam
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Isle of Man
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Japan
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kosovo
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kuwait
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Lebanon
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for New Caledonia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Qatar
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for San Marino
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Seychelles
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Aruba
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Australia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bahrain
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Barbados
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bermuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Cayman Islands
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Dominica
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for French Polynesia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Gibraltar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Grenada
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Guam
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Isle of Man
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Japan
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kosovo
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kuwait
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Lebanon
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Monaco
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for New Caledonia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Qatar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for San Marino
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Seychelles
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Singapore
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Aruba
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Australia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Bahrain
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Barbados
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Dominica
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for French Polynesia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Grenada
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Guam
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Isle of Man
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Japan
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kosovo
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kuwait
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Lebanon
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for New Caledonia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Qatar
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for San Marino
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Seychelles
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for United Arab Emirates
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Bermuda
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Cayman Islands
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Gibraltar
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kosovo
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kuwait
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Monaco
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Singapore
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Andorra
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Cayman Islands
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for French Polynesia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Greenland
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Guam
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Haiti
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Iraq
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Isle of Man
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Japan
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Kosovo
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Lebanon
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Monaco
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Namibia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for New Caledonia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Andorra
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cambodia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cayman Islands
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Equatorial Guinea
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for French Polynesia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Gabon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Greenland
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Guam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Haiti
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Iraq
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Isle of Man
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Japan
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kenya
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kosovo
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Lebanon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Maldives
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Monaco
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Namibia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for New Caledonia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Trinidad and Tobago
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Uganda
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Vietnam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Zambia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Andorra
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bolivia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Cayman Islands
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Dominica
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Equatorial Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Fiji
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for French Polynesia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gabon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gibraltar
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Greenland
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Guam
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Haiti
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Iraq
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Isle of Man
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Japan
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Kosovo
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Lebanon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Monaco
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Namibia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for New Caledonia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Nicaragua
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Papua New Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Somalia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Suriname
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Trinidad and Tobago
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Turkey
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for United Arab Emirates
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Aruba
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bangladesh
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bermuda
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Cayman Islands
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for French Polynesia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Gibraltar
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Greenland
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Guam
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Isle of Man
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kosovo
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kuwait
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Liechtenstein
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Mauritania
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Monaco
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for New Caledonia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for San Marino
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Somalia
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Andorra
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Bermuda
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Cayman Islands
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Dominica
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Gibraltar
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Greenland
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Isle of Man
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Kosovo
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Liechtenstein
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Monaco
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for San Marino

# %%
#https://en.wikipedia.org/wiki/Andorra_la_Vella
for i in df[df["Country Name"]=="Andorra"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 22886
    
#https://en.wikipedia.org/wiki/St._John%27s,_Antigua_and_Barbuda
for i in df[df["Country Name"]=="Antigua and Barbuda"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 21926
    
#https://worldpopulationreview.com/countries/aruba-population/cities/
for i in df[df["Country Name"]=="Aruba"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 29998

#https://worldpopulationreview.com/countries/barbados-population/cities/
for i in df[df["Country Name"]=="Barbados"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 98511
    
#https://population.mongabay.com/population/bermuda/    
for i in df[df["Country Name"]=="Bermuda"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 1896

#https://www.geonames.org/BT/largest-cities-in-bhutan.html
for i in df[df["Country Name"]=="Bhutan"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 98676
    
#https://en.wikipedia.org/wiki/George_Town,_Cayman_Islands
for i in df[df["Country Name"]=="Cayman Islands"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 40200
    
#https://simple.wikipedia.org/wiki/Nicosia
for i in df[df["Country Name"]=="Cyprus"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 310355
    
#https://www.geonames.org/DM/largest-cities-in-dominica.html
for i in df[df["Country Name"]=="Dominica"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 16571

#https://tr.wikipedia.org/wiki/Suva
for i in df[df["Country Name"]=="Fiji"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 85691
    
#https://en.wikipedia.org/wiki/Faaa
for i in df[df["Country Name"]=="French Polynesia"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 29506
    
#https://population.mongabay.com/population/gibraltar
for i in df[df["Country Name"]=="Gibraltar"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 26544
    
#https://en.wikipedia.org/wiki/List_of_cities_and_towns_in_Greenland
for i in df[df["Country Name"]=="Greenland"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 17984
    
#https://population.mongabay.com/population/grenada
for i in df[df["Country Name"]=="Grenada"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 7500
    
#https://www.geonames.org/GU/largest-cities-in-guam.html
for i in df[df["Country Name"]=="Guam"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 44943
    
#https://www.geonames.org/GY/largest-cities-in-guyana.html
for i in df[df["Country Name"]=="Guyana"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 235017
    
#https://en.wikipedia.org/wiki/Localities_of_Iceland
for i in df[df["Country Name"]=="Iceland"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 124847

#https://www.geonames.org/IM/largest-cities-in-isle-of-man.html
for i in df[df["Country Name"]=="Isle of Man"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 26218
    
#https://population.mongabay.com/population/kosovo/
for i in df[df["Country Name"]=="Kosovo"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 550000
    
#https://population.mongabay.com/population/liechtenstein/
for i in df[df["Country Name"]=="Liechtenstein"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 5748
    
#https://www.geonames.org/LU/largest-cities-in-luxembourg.html
for i in df[df["Country Name"]=="Luxembourg"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 76684
    
#https://www.geonames.org/MV/largest-cities-in-maldives.html
for i in df[df["Country Name"]=="Maldives"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 103693
    
#https://www.geonames.org/MT/largest-cities-in-malta.html
for i in df[df["Country Name"]=="Malta"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 21676
    
#https://population.mongabay.com/population/mauritius/
for i in df[df["Country Name"]=="Mauritius"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 155226
    
#https://population.mongabay.com/population/monaco/
for i in df[df["Country Name"]=="Monaco"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 32965
    
#https://worldpopulationreview.com/countries/montenegro-population/cities/
for i in df[df["Country Name"]=="Montenegro"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 136473
    
#https://population.mongabay.com/population/new-caledonia/
for i in df[df["Country Name"]=="New Caledonia"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 93060
    
#https://www.geonames.org/SM/largest-cities-in-san-marino.html
for i in df[df["Country Name"]=="San Marino"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 9258
    
#https://worldpopulationreview.com/countries/seychelles-population/cities/
for i in df[df["Country Name"]=="Seychelles"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 22881
    
#https://www.geonames.org/SI/largest-cities-in-slovenia.html
for i in df[df["Country Name"]=="Slovenia"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 272200
    
#https://www.geonames.org/SR/largest-cities-in-suriname.html
for i in df[df["Country Name"]=="Suriname"].index:
    df.loc[i,"Population in largest city [EN.URB.LCTY]"] = 223757

# %% [markdown]
# My job is done with "Population in largest city" feature.

# %%
dfcountrycheck = df.groupby(by = "Country Name").sum()

for feature in features_can_found_manually:
    for country in dfcountrycheck.index:
        if dfcountrycheck.loc[country,feature] == 0:
            print("{} is missing for {}".format(feature,country))
# Out:
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Andorra
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Dominica
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Gibraltar
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Isle of Man
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN] is missing for Monaco
# Labor force, total [SL.TLF.TOTL.IN] is missing for Andorra
# Labor force, total [SL.TLF.TOTL.IN] is missing for Antigua and Barbuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Aruba
# Labor force, total [SL.TLF.TOTL.IN] is missing for Bermuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Cayman Islands
# Labor force, total [SL.TLF.TOTL.IN] is missing for Dominica
# Labor force, total [SL.TLF.TOTL.IN] is missing for Gibraltar
# Labor force, total [SL.TLF.TOTL.IN] is missing for Greenland
# Labor force, total [SL.TLF.TOTL.IN] is missing for Grenada
# Labor force, total [SL.TLF.TOTL.IN] is missing for Isle of Man
# Labor force, total [SL.TLF.TOTL.IN] is missing for Kosovo
# Labor force, total [SL.TLF.TOTL.IN] is missing for Liechtenstein
# Labor force, total [SL.TLF.TOTL.IN] is missing for Monaco
# Labor force, total [SL.TLF.TOTL.IN] is missing for San Marino
# Labor force, total [SL.TLF.TOTL.IN] is missing for Seychelles
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Andorra
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Australia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Austria
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Belgium
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Bermuda
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Canada
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Cayman Islands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Czech Republic
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Denmark
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Djibouti
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Dominica
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Finland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for France
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for French Polynesia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Germany
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Gibraltar
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Greenland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Guam
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Iceland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Ireland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Isle of Man
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Israel
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Japan
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Kosovo
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Liechtenstein
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Luxembourg
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Monaco
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Namibia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Netherlands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for New Zealand
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Norway
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Poland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Somalia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Sweden
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Switzerland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Arab Emirates
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Kingdom
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United States
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Andorra
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Antigua and Barbuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Australia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Austria
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Belgium
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Bermuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Canada
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Cayman Islands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Czech Republic
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Denmark
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Djibouti
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Dominica
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Finland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for France
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for French Polynesia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Germany
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Gibraltar
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Greenland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Guam
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Iceland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Ireland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Isle of Man
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Israel
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Japan
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Kosovo
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Liechtenstein
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Luxembourg
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Monaco
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Namibia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Netherlands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for New Zealand
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Norway
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Poland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Somalia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Sweden
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Switzerland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Arab Emirates
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Kingdom
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United States
# Net migration [SM.POP.NETM] is missing for Andorra
# Net migration [SM.POP.NETM] is missing for Antigua and Barbuda
# Net migration [SM.POP.NETM] is missing for Bermuda
# Net migration [SM.POP.NETM] is missing for Cayman Islands
# Net migration [SM.POP.NETM] is missing for Dominica
# Net migration [SM.POP.NETM] is missing for Gibraltar
# Net migration [SM.POP.NETM] is missing for Greenland
# Net migration [SM.POP.NETM] is missing for Isle of Man
# Net migration [SM.POP.NETM] is missing for Kosovo
# Net migration [SM.POP.NETM] is missing for Liechtenstein
# Net migration [SM.POP.NETM] is missing for Mauritius
# Net migration [SM.POP.NETM] is missing for Monaco
# Net migration [SM.POP.NETM] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Aruba
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bahrain
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Barbados
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bermuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Cayman Islands
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Dominica
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for French Polynesia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Gibraltar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Grenada
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Guam
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Isle of Man
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Japan
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kosovo
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kuwait
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Lebanon
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Monaco
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for New Caledonia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Qatar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Seychelles
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Singapore
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for United Arab Emirates
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Aruba
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Bahrain
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Barbados
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Dominica
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for French Polynesia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Grenada
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Guam
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Isle of Man
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Japan
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kosovo
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kuwait
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Lebanon
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for New Caledonia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Qatar
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for San Marino
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Seychelles
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Aruba
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Australia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bahrain
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Barbados
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bermuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Cayman Islands
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Dominica
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for French Polynesia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Gibraltar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Grenada
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Guam
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Isle of Man
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Japan
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kosovo
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kuwait
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Lebanon
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Monaco
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for New Caledonia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Qatar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for San Marino
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Seychelles
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Singapore
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Aruba
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Australia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Bahrain
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Barbados
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Dominica
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for French Polynesia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Grenada
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Guam
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Isle of Man
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Japan
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kosovo
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kuwait
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Lebanon
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for New Caledonia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Qatar
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for San Marino
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Seychelles
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for United Arab Emirates
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Bermuda
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Cayman Islands
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Gibraltar
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kosovo
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kuwait
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Monaco
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Singapore
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Andorra
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Cayman Islands
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for French Polynesia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Greenland
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Guam
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Haiti
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Iraq
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Isle of Man
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Japan
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Kosovo
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Lebanon
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Monaco
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Namibia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for New Caledonia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Andorra
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cambodia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cayman Islands
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Equatorial Guinea
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for French Polynesia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Gabon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Greenland
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Guam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Haiti
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Iraq
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Isle of Man
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Japan
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kenya
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kosovo
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Lebanon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Maldives
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Monaco
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Namibia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for New Caledonia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Trinidad and Tobago
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Uganda
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Vietnam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Zambia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Andorra
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bolivia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Cayman Islands
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Dominica
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Equatorial Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Fiji
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for French Polynesia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gabon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gibraltar
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Greenland
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Guam
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Haiti
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Iraq
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Isle of Man
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Japan
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Kosovo
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Lebanon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Monaco
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Namibia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for New Caledonia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Nicaragua
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Papua New Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Somalia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Suriname
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Trinidad and Tobago
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Turkey
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for United Arab Emirates
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Aruba
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bangladesh
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bermuda
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Cayman Islands
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for French Polynesia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Gibraltar
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Greenland
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Guam
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Isle of Man
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kosovo
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kuwait
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Liechtenstein
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Mauritania
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Monaco
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for New Caledonia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for San Marino
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Somalia
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Andorra
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Bermuda
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Cayman Islands
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Dominica
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Gibraltar
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Greenland
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Isle of Man
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Kosovo
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Liechtenstein
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Monaco
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for San Marino

# %%
#https://www.indexmundi.com/andorra/life_expectancy_at_birth.html
for i in df[df["Country Name"]=="Andorra"].index:
    df.loc[i,"Life expectancy at birth, total (years) [SP.DYN.LE00.IN]"] = float(82.9)
    
#https://data.worldbank.org/indicator/SP.DYN.LE00.IN?locations=DM
for i in df[df["Country Name"]=="Dominica"].index:
    df.loc[i,"Life expectancy at birth, total (years) [SP.DYN.LE00.IN]"] = float(76.6)
    
#https://www.indexmundi.com/gibraltar/life_expectancy_at_birth.html
for i in df[df["Country Name"]=="Gibraltar"].index:
    df.loc[i,"Life expectancy at birth, total (years) [SP.DYN.LE00.IN]"] = float(79.7)
    
#https://www.indexmundi.com/isle_of_man/life_expectancy_at_birth.html
for i in df[df["Country Name"]=="Isle of Man"].index:
    df.loc[i,"Life expectancy at birth, total (years) [SP.DYN.LE00.IN]"] = float(81.4)
    
#https://www.indexmundi.com/monaco/life_expectancy_at_birth.html
for i in df[df["Country Name"]=="Monaco"].index:
    df.loc[i,"Life expectancy at birth, total (years) [SP.DYN.LE00.IN]"] = float(89.4)

# %% [markdown]
# My job is done with "Life expectancy at birth"

# %%
dfcountrycheck = df.groupby(by = "Country Name").sum()

for feature in features_can_found_manually:
    for country in dfcountrycheck.index:
        if dfcountrycheck.loc[country,feature] == 0:
            print("{} is missing for {}".format(feature,country))
# Out:
# Labor force, total [SL.TLF.TOTL.IN] is missing for Andorra
# Labor force, total [SL.TLF.TOTL.IN] is missing for Antigua and Barbuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Aruba
# Labor force, total [SL.TLF.TOTL.IN] is missing for Bermuda
# Labor force, total [SL.TLF.TOTL.IN] is missing for Cayman Islands
# Labor force, total [SL.TLF.TOTL.IN] is missing for Dominica
# Labor force, total [SL.TLF.TOTL.IN] is missing for Gibraltar
# Labor force, total [SL.TLF.TOTL.IN] is missing for Greenland
# Labor force, total [SL.TLF.TOTL.IN] is missing for Grenada
# Labor force, total [SL.TLF.TOTL.IN] is missing for Isle of Man
# Labor force, total [SL.TLF.TOTL.IN] is missing for Kosovo
# Labor force, total [SL.TLF.TOTL.IN] is missing for Liechtenstein
# Labor force, total [SL.TLF.TOTL.IN] is missing for Monaco
# Labor force, total [SL.TLF.TOTL.IN] is missing for San Marino
# Labor force, total [SL.TLF.TOTL.IN] is missing for Seychelles
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Andorra
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Australia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Austria
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Belgium
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Bermuda
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Canada
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Cayman Islands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Czech Republic
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Denmark
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Djibouti
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Dominica
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Finland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for France
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for French Polynesia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Germany
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Gibraltar
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Greenland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Guam
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Iceland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Ireland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Isle of Man
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Israel
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Japan
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Kosovo
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Liechtenstein
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Luxembourg
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Monaco
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Namibia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Netherlands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for New Zealand
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Norway
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Poland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Somalia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Sweden
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Switzerland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Arab Emirates
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Kingdom
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United States
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Andorra
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Antigua and Barbuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Australia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Austria
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Belgium
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Bermuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Canada
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Cayman Islands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Czech Republic
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Denmark
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Djibouti
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Dominica
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Finland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for France
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for French Polynesia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Germany
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Gibraltar
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Greenland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Guam
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Iceland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Ireland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Isle of Man
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Israel
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Japan
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Kosovo
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Liechtenstein
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Luxembourg
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Monaco
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Namibia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Netherlands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for New Zealand
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Norway
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Poland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Somalia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Sweden
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Switzerland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Arab Emirates
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Kingdom
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United States
# Net migration [SM.POP.NETM] is missing for Andorra
# Net migration [SM.POP.NETM] is missing for Antigua and Barbuda
# Net migration [SM.POP.NETM] is missing for Bermuda
# Net migration [SM.POP.NETM] is missing for Cayman Islands
# Net migration [SM.POP.NETM] is missing for Dominica
# Net migration [SM.POP.NETM] is missing for Gibraltar
# Net migration [SM.POP.NETM] is missing for Greenland
# Net migration [SM.POP.NETM] is missing for Isle of Man
# Net migration [SM.POP.NETM] is missing for Kosovo
# Net migration [SM.POP.NETM] is missing for Liechtenstein
# Net migration [SM.POP.NETM] is missing for Mauritius
# Net migration [SM.POP.NETM] is missing for Monaco
# Net migration [SM.POP.NETM] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Aruba
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bahrain
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Barbados
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bermuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Cayman Islands
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Dominica
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for French Polynesia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Gibraltar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Grenada
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Guam
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Isle of Man
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Japan
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kosovo
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kuwait
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Lebanon
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Monaco
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for New Caledonia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Qatar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Seychelles
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Singapore
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for United Arab Emirates
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Aruba
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Bahrain
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Barbados
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Dominica
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for French Polynesia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Grenada
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Guam
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Isle of Man
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Japan
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kosovo
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kuwait
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Lebanon
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for New Caledonia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Qatar
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for San Marino
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Seychelles
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Aruba
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Australia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bahrain
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Barbados
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bermuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Cayman Islands
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Dominica
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for French Polynesia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Gibraltar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Grenada
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Guam
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Isle of Man
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Japan
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kosovo
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kuwait
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Lebanon
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Monaco
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for New Caledonia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Qatar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for San Marino
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Seychelles
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Singapore
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Aruba
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Australia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Bahrain
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Barbados
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Dominica
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for French Polynesia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Grenada
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Guam
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Isle of Man
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Japan
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kosovo
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kuwait
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Lebanon
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for New Caledonia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Qatar
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for San Marino
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Seychelles
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for United Arab Emirates
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Bermuda
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Cayman Islands
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Gibraltar
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kosovo
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kuwait
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Monaco
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Singapore
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Andorra
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Cayman Islands
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for French Polynesia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Greenland
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Guam
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Haiti
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Iraq
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Isle of Man
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Japan
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Kosovo
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Lebanon
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Monaco
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Namibia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for New Caledonia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Andorra
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cambodia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cayman Islands
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Equatorial Guinea
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for French Polynesia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Gabon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Greenland
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Guam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Haiti
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Iraq
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Isle of Man
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Japan
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kenya
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kosovo
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Lebanon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Maldives
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Monaco
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Namibia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for New Caledonia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Trinidad and Tobago
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Uganda
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Vietnam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Zambia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Andorra
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bolivia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Cayman Islands
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Dominica
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Equatorial Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Fiji
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for French Polynesia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gabon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gibraltar
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Greenland
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Guam
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Haiti
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Iraq
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Isle of Man
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Japan
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Kosovo
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Lebanon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Monaco
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Namibia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for New Caledonia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Nicaragua
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Papua New Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Somalia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Suriname
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Trinidad and Tobago
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Turkey
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for United Arab Emirates
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Aruba
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bangladesh
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bermuda
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Cayman Islands
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for French Polynesia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Gibraltar
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Greenland
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Guam
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Isle of Man
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kosovo
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kuwait
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Liechtenstein
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Mauritania
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Monaco
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for New Caledonia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for San Marino
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Somalia
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Andorra
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Bermuda
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Cayman Islands
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Dominica
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Gibraltar
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Greenland
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Isle of Man
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Kosovo
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Liechtenstein
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Monaco
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for San Marino

# %%
#https://www.indexmundi.com/andorra/labor_force.html
for i in df[df["Country Name"]=="Andorra"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 39750
    
#https://www.nationmaster.com/country-info/profiles/Antigua-and-Barbuda/Labor
for i in df[df["Country Name"]=="Antigua and Barbuda"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 30000
    
#https://www.indexmundi.com/aruba/labor_force.html
for i in df[df["Country Name"]=="Aruba"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 51610
    
#https://www.gov.bm/articles/2018-labour-force-survey
for i in df[df["Country Name"]=="Bermuda"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 36646
    
#http://www.gov.ky/portal/page/portal/cighome/pressroom/archive/201709/Labour%20Force%20Has%20Grown
for i in df[df["Country Name"]=="Cayman Islands"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 43545
    
#https://www.ceicdata.com/en/indicator/kosovo/labour-force-participation-rate
for i in df[df["Country Name"]=="Kosovo"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 40500
    
#https://www.indexmundi.com/liechtenstein/labor_force.html
for i in df[df["Country Name"]=="Liechtenstein"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 38520
    
#https://www.indexmundi.com/monaco/labor_force.html
for i in df[df["Country Name"]=="Monaco"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 52000
    
#https://www.economy.com/san-marino/labor-force
for i in df[df["Country Name"]=="San Marino"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 22577
    
#https://www.ceicdata.com/en/seychelles/labour-force
for i in df[df["Country Name"]=="Seychelles"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 71130
    
#https://www.nationmaster.com/country-info/profiles/Dominica/Labor
for i in df[df["Country Name"]=="Dominica"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 25000
    
#https://theodora.com/wfbcurrent/gibraltar/gibraltar_economy.html
for i in df[df["Country Name"]=="Gibraltar"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 24420
    
#https://www.cia.gov/library/publications/the-world-factbook/geos/print_gl.html
for i in df[df["Country Name"]=="Greenland"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 26840
    
#https://www.indexmundi.com/grenada/labor_force.html
for i in df[df["Country Name"]=="Grenada"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 55270
    
#https://www.indexmundi.com/isle_of_man/labor_force.html
for i in df[df["Country Name"]=="Isle of Man"].index:
    df.loc[i,"Labor force, total [SL.TLF.TOTL.IN]"] = 41790

# %% [markdown]
# My job is done with "Labor force, total". I will prefer to go on with excel for the rest of the manual process.
#
#
# Literacy Rate:
# Andorra
# https://www.indexmundi.com/andorra/literacy.html
#
# Australia
# https://www.aihw.gov.au/reports/children-youth/childrens-headline-indicators/contents/12-literacy
#
# Austria
# https://www.indexmundi.com/austria/literacy.html
#
# Belgium
# https://www.indexmundi.com/belgium/literacy.html
#
# Bermuda
# https://www.ncbi.nlm.nih.gov/pubmed/12178115
#
# Cayman Islands
# https://en.wikipedia.org/wiki/Education_in_the_Cayman_Islands
#
# Djibouti
# https://www.indexmundi.com/djibouti/literacy.html
#
# French Polynesia
# https://www.indexmundi.com/french_polynesia/literacy.html
#
# Gibraltar
# http://www.phrasebase.com/countries/gibraltar/
#
# Greenland
# http://www.phrasebase.com/countries/greenland/
#
# Guam
# https://www.indexmundi.com/guam/literacy.html
#
# Iceland
# https://www.indexmundi.com/iceland/literacy.html
#
# Ireland
# https://www.indexmundi.com/ireland/literacy.html
#
# Kosovo
# https://www.indexmundi.com/kosovo/literacy.html
#
# For Rest
# https://www.worldatlas.com/articles/the-highest-literacy-rates-in-the-world.html
#
# Alcohol Consumption per capita:
# https://www.who.int/substance_abuse/publications/global_status_report_2004_overview.pdf

# %%
# Out:
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Andorra
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Australia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Austria
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Belgium
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Bermuda
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Canada
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Cayman Islands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Czech Republic
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Denmark
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Djibouti
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Dominica
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Finland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for France
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for French Polynesia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Germany
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Gibraltar
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Greenland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Guam
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Iceland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Ireland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Isle of Man
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Israel
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Japan
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Kosovo
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Liechtenstein
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Luxembourg
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Monaco
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Namibia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Netherlands
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for New Zealand
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Norway
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Poland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Somalia
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Sweden
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for Switzerland
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Arab Emirates
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United Kingdom
# Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS] is missing for United States
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Andorra
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Antigua and Barbuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Australia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Austria
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Belgium
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Bermuda
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Canada
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Cayman Islands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Czech Republic
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Denmark
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Djibouti
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Dominica
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Finland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for France
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for French Polynesia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Germany
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Gibraltar
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Greenland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Guam
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Iceland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Ireland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Isle of Man
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Israel
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Japan
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Kosovo
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Liechtenstein
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Luxembourg
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Monaco
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Namibia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Netherlands
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for New Zealand
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Norway
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Poland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Somalia
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Sweden
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for Switzerland
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Arab Emirates
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United Kingdom
# Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS] is missing for United States
# Net migration [SM.POP.NETM] is missing for Andorra
# Net migration [SM.POP.NETM] is missing for Antigua and Barbuda
# Net migration [SM.POP.NETM] is missing for Bermuda
# Net migration [SM.POP.NETM] is missing for Cayman Islands
# Net migration [SM.POP.NETM] is missing for Dominica
# Net migration [SM.POP.NETM] is missing for Gibraltar
# Net migration [SM.POP.NETM] is missing for Greenland
# Net migration [SM.POP.NETM] is missing for Isle of Man
# Net migration [SM.POP.NETM] is missing for Kosovo
# Net migration [SM.POP.NETM] is missing for Liechtenstein
# Net migration [SM.POP.NETM] is missing for Mauritius
# Net migration [SM.POP.NETM] is missing for Monaco
# Net migration [SM.POP.NETM] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Aruba
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bahrain
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Barbados
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Bermuda
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Cayman Islands
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Dominica
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for French Polynesia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Gibraltar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Grenada
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Guam
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Isle of Man
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Japan
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kosovo
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Kuwait
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Lebanon
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Monaco
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for New Caledonia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Qatar
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for San Marino
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Seychelles
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Singapore
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS] is missing for United Arab Emirates
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Aruba
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Bahrain
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Barbados
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Dominica
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for French Polynesia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Grenada
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Guam
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Isle of Man
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Japan
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kosovo
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Kuwait
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Lebanon
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Liechtenstein
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for New Caledonia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Qatar
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for San Marino
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Saudi Arabia
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Seychelles
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Aruba
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Australia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bahrain
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Barbados
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Bermuda
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Cayman Islands
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Dominica
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for French Polynesia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Gibraltar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Grenada
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Guam
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Isle of Man
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Japan
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kosovo
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Kuwait
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Lebanon
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Monaco
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for New Caledonia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Qatar
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for San Marino
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Seychelles
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Singapore
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS] is missing for United Arab Emirates
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Antigua and Barbuda
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Aruba
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Australia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Bahrain
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Barbados
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Dominica
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for French Polynesia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Grenada
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Guam
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Isle of Man
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Japan
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kosovo
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Kuwait
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Lebanon
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Liechtenstein
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for New Caledonia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Qatar
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for San Marino
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Saudi Arabia
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Seychelles
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for Trinidad and Tobago
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS] is missing for United Arab Emirates
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Bermuda
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Cayman Islands
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Gibraltar
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kosovo
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Kuwait
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Monaco
# Rural population (% of total population) [SP.RUR.TOTL.ZS] is missing for Singapore
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Andorra
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Cayman Islands
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for French Polynesia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Greenland
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Guam
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Haiti
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Iraq
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Isle of Man
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Japan
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Kosovo
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Lebanon
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Monaco
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Namibia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for New Caledonia
# School enrollment, primary (% gross) [SE.PRM.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Andorra
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cambodia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Cayman Islands
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Equatorial Guinea
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for French Polynesia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Gabon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Greenland
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Guam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Haiti
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Iraq
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Isle of Man
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Japan
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kenya
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Kosovo
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Lebanon
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Maldives
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Monaco
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Namibia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for New Caledonia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Somalia
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Trinidad and Tobago
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Uganda
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Vietnam
# School enrollment, secondary (% gross) [SE.SEC.ENRR] is missing for Zambia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Andorra
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bolivia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Bosnia and Herzegovina
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Cayman Islands
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Dominica
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Equatorial Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Fiji
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for French Polynesia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gabon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Gibraltar
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Greenland
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Guam
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Haiti
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Iraq
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Isle of Man
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Japan
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Kosovo
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Lebanon
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Monaco
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Namibia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for New Caledonia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Nicaragua
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Papua New Guinea
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Somalia
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Suriname
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Trinidad and Tobago
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for Turkey
# School enrollment, tertiary (% gross) [SE.TER.ENRR] is missing for United Arab Emirates
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Aruba
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bangladesh
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Bermuda
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Cayman Islands
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for French Polynesia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Gibraltar
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Greenland
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Guam
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Isle of Man
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kosovo
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Kuwait
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Liechtenstein
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Mauritania
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Monaco
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for New Caledonia
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for San Marino
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI] is missing for Somalia
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Andorra
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Bermuda
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Cayman Islands
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Dominica
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Gibraltar
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Greenland
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Isle of Man
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Kosovo
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Liechtenstein
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for Monaco
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG] is missing for San Marino

# %%
df = pd.read_csv("data14-4-2020.csv")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1 Country Name  total_cases  total_deaths  \
# 0              0             0  Afghanistan            1             0
# 1              1             1  Afghanistan            1             0
# 2              2             2  Afghanistan            1             0
# 3              3             3  Afghanistan            1             0
# 4              4             4  Afghanistan            1             0
# ...          ...           ...          ...          ...           ...
# 5095        5095          5095     Zimbabwe            8             1
# 5096        5096          5096     Zimbabwe            8             1
# 5097        5097          5097     Zimbabwe            9             1
# 5098        5098          5098     Zimbabwe            9             1
# 5099        5099          5099     Zimbabwe            9             1
#
#      continent  population  Year  \
# 0         Asia    38928341  2020
# 1         Asia    38928341  2020
# 2         Asia    38928341  2020
# 3         Asia    38928341  2020
# 4         Asia    38928341  2020
# ...        ...         ...   ...
# 5095    Africa    14862927  2020
# 5096    Africa    14862927  2020
# 5097    Africa    14862927  2020
# 5098    Africa    14862927  2020
# 5099    Africa    14862927  2020
#
#       Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                  50.5
# 1                                                  50.5
# 2                                                  50.5
# 3                                                  50.5
# 4                                                  50.5
# ...                                                 ...
# 5095                                               78.1
# 5096                                               78.1
# 5097                                               78.1
# 5098                                               78.1
# 5099                                               78.1
#
#       Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]  \
# 0                                             57.248760
# 1                                             57.248760
# 2                                             57.248760
# 3                                             57.248760
# 4                                             57.248760
# ...                                                 ...
# 5095                                          93.942225
# 5096                                          93.942225
# 5097                                          93.942225
# 5098                                          93.942225
# 5099                                          93.942225
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5095  ...
# 5096  ...
# 5097  ...
# 5098  ...
# 5099  ...
#
#       Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]  \
# 0                                             42.331198
# 1                                             42.331198
# 2                                             42.331198
# 3                                             42.331198
# 4                                             42.331198
# ...                                                 ...
# 5095                                          32.576344
# 5096                                          32.576344
# 5097                                          32.576344
# 5098                                          32.576344
# 5099                                          32.576344
#
#       Population in largest city [EN.URB.LCTY]  \
# 0                                    4011770.0
# 1                                    4011770.0
# 2                                    4011770.0
# 3                                    4011770.0
# 4                                    4011770.0
# ...                                        ...
# 5095                                 1515016.0
# 5096                                 1515016.0
# 5097                                 1515016.0
# 5098                                 1515016.0
# 5099                                 1515016.0
#
#       Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]  \
# 0                                              4.758273
# 1                                              4.758273
# 2                                              4.758273
# 3                                              4.758273
# 4                                              4.758273
# ...                                                 ...
# 5095                                           5.377887
# 5096                                           5.377887
# 5097                                           5.377887
# 5098                                           5.377887
# 5099                                           5.377887
#
#       Age dependency ratio (% of working-age population) [SP.POP.DPND]  \
# 0                                             84.077656
# 1                                             84.077656
# 2                                             84.077656
# 3                                             84.077656
# 4                                             84.077656
# ...                                                 ...
# 5095                                          82.951116
# 5096                                          82.951116
# 5097                                          82.951116
# 5098                                          82.951116
# 5099                                          82.951116
#
#       Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]  \
# 0                                            466.079081
# 1                                            466.079081
# 2                                            466.079081
# 3                                            466.079081
# 4                                            466.079081
# ...                                                 ...
# 5095                                        1142.940418
# 5096                                        1142.940418
# 5097                                        1142.940418
# 5098                                        1142.940418
# 5099                                        1142.940418
#
#       Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]  \
# 0                                              32.27117
# 1                                              32.27117
# 2                                              32.27117
# 3                                              32.27117
# 4                                              32.27117
# ...                                                 ...
# 5095                                           11.71069
# 5096                                           11.71069
# 5097                                           11.71069
# 5098                                           11.71069
# 5099                                           11.71069
#
#       Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]  2 weeks  \
# 0                                                125.41            True
# 1                                                125.41            True
# 2                                                125.41            True
# 3                                                125.41            True
# 4                                                125.41            True
# ...                                                 ...             ...
# 5095                                              88.75            True
# 5096                                              88.75            True
# 5097                                              88.75            True
# 5098                                              88.75            True
# 5099                                              88.75            True
#
#       4 weeks  +8 weeks
# 0        True     False
# 1        True     False
# 2        True     False
# 3        True     False
# 4        True     False
# ...       ...       ...
# 5095    False     False
# 5096    False     False
# 5097    False     False
# 5098    False     False
# 5099    False     False
#
# [5100 rows x 54 columns]

# %%
missing_percentage = df.isnull().sum()*100/df.shape[0]

missing_percentage = missing_percentage[missing_percentage>0]

missing_percentage
# Out:
# Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                                                    15.862745
# Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]                                                   4.490196
# Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]                                  4.490196
# Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]                                                      1.470588
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]                   14.862745
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]                   11.843137
# People using at least basic sanitation services (% of population) [SH.STA.BASS.ZS]                                        0.333333
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]                       16.294118
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]                      13.274510
# Rural population (% of total population) [SP.RUR.TOTL.ZS]                                                                 0.431373
# School enrollment, primary (% gross) [SE.PRM.ENRR]                                                                        8.019608
# School enrollment, secondary (% gross) [SE.SEC.ENRR]                                                                     13.705882
# School enrollment, tertiary (% gross) [SE.TER.ENRR]                                                                      13.725490
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]     3.921569
# Urban population (% of total population) [SP.URB.TOTL.IN.ZS]                                                              0.431373
# Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]                                                4.725490
# Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                                 5.450980
# Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                             4.882353
# Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]                  4.882353
# Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]                      5.450980
# Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                               4.882353
# Domestic general government health expenditure per capita, PPP (current international $) [SH.XPD.GHED.PP.CD]              4.882353
# Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                                 5.450980
# Domestic private health expenditure per capita (current US$) [SH.XPD.PVTD.PC.CD]                                          5.450980
# Domestic private health expenditure per capita, PPP (current international $) [SH.XPD.PVTD.PP.CD]                         5.450980
# External health expenditure per capita, PPP (current international $) [SH.XPD.EHEX.PP.CD]                                 4.882353
# External health expenditure per capita (current US$) [SH.XPD.EHEX.PC.CD]                                                  4.882353
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                         0.470588
# Land area (sq. km) [AG.LND.TOTL.K2]                                                                                       0.470588
# Urban land area (sq. km) [AG.LND.TOTL.UR.K2]                                                                             13.333333
# Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]                                               13.529412
# Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]                                                  4.725490
# Age dependency ratio (% of working-age population) [SP.POP.DPND]                                                          4.725490
# Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]                                                 7.705882
# Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]                                                               8.058824
# Food production index (2004-2006 = 100) [AG.PRD.FOOD.XD]                                                                  3.137255
# dtype: float64

# %% [markdown]
# Our data is not good for interpolation since every country have discrete and unique values.
# So we will fill the missing with the median of countries' continent on given feature.

# %%
for feature in df:    
    for index in df[df[feature].isnull()].index:
        for continent in df["continent"].unique():
            df.loc[index,feature] = np.median(df[df["continent"] ==continent][feature])

# %%
missing_percentage = df.isnull().sum()*100/df.shape[0]

missing_percentage = missing_percentage[missing_percentage>0]

missing_percentage
# Out:
# Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                                                    15.862745
# Current health expenditure per capita (current US$) [SH.XPD.CHEX.PC.CD]                                                   4.490196
# Current health expenditure per capita, PPP (current international $) [SH.XPD.CHEX.PP.CD]                                  4.490196
# People using at least basic drinking water services, rural (% of rural population) [SH.H2O.BASW.RU.ZS]                   14.862745
# People using at least basic drinking water services, urban (% of urban population) [SH.H2O.BASW.UR.ZS]                   11.843137
# People using at least basic sanitation services, rural (% of rural population) [SH.STA.BASS.RU.ZS]                       16.294118
# People using at least basic sanitation services, urban  (% of urban population) [SH.STA.BASS.UR.ZS]                      13.274510
# School enrollment, primary (% gross) [SE.PRM.ENRR]                                                                        8.019608
# School enrollment, secondary (% gross) [SE.SEC.ENRR]                                                                     13.705882
# School enrollment, tertiary (% gross) [SE.TER.ENRR]                                                                      13.725490
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) [SH.ALC.PCAP.LI]     3.156863
# Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                                 5.450980
# Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                             4.882353
# Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]                  4.882353
# Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]                      5.450980
# Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                               4.882353
# Domestic general government health expenditure per capita, PPP (current international $) [SH.XPD.GHED.PP.CD]              4.882353
# Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                                 5.450980
# Domestic private health expenditure per capita (current US$) [SH.XPD.PVTD.PC.CD]                                          5.450980
# Domestic private health expenditure per capita, PPP (current international $) [SH.XPD.PVTD.PP.CD]                         5.450980
# External health expenditure per capita, PPP (current international $) [SH.XPD.EHEX.PP.CD]                                 4.882353
# External health expenditure per capita (current US$) [SH.XPD.EHEX.PC.CD]                                                  4.882353
# Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]                                               13.529412
# Adjusted net national income per capita (current US$) [NY.ADJ.NNTY.PC.CD]                                                 7.705882
# Food imports (% of merchandise imports) [TM.VAL.FOOD.ZS.UN]                                                               8.058824
# dtype: float64
