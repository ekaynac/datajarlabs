# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("full_data.csv")
df
# Out:
#             date     location  new_cases  new_deaths  total_cases  \
# 0     2019-12-31  Afghanistan          0           0            0
# 1     2020-01-01  Afghanistan          0           0            0
# 2     2020-01-02  Afghanistan          0           0            0
# 3     2020-01-03  Afghanistan          0           0            0
# 4     2020-01-04  Afghanistan          0           0            0
# ...          ...          ...        ...         ...          ...
# 9136  2020-04-02     Zimbabwe          0           0            8
# 9137  2020-04-03     Zimbabwe          0           0            8
# 9138  2020-04-04     Zimbabwe          1           0            9
# 9139  2020-04-05     Zimbabwe          0           0            9
# 9140  2020-04-06     Zimbabwe          0           0            9
#
#       total_deaths continent  population_year  population
# 0                0      Asia             2020    38928341
# ...

# %%
df_nnzero = df[df.total_cases != 0]
df_nnzero
# Out:
#             date     location  new_cases  new_deaths  total_cases  \
# 56    2020-02-25  Afghanistan          1           0            1
# 57    2020-02-26  Afghanistan          0           0            1
# 58    2020-02-27  Afghanistan          0           0            1
# 59    2020-02-28  Afghanistan          0           0            1
# 60    2020-02-29  Afghanistan          0           0            1
# ...          ...          ...        ...         ...          ...
# 9136  2020-04-02     Zimbabwe          0           0            8
# 9137  2020-04-03     Zimbabwe          0           0            8
# 9138  2020-04-04     Zimbabwe          1           0            9
# 9139  2020-04-05     Zimbabwe          0           0            9
# 9140  2020-04-06     Zimbabwe          0           0            9
#
#       total_deaths continent  population_year  population
# 56               0      Asia             2020    38928341
# ...

# %%
df_nnzero.groupby(by="location").count().mean()["date"]
# Out:
# 30.078048780487805

# %% [markdown]
# Ask for how many country we have data of more than 30 days?

# %%
x = 0
y = 0
threshold = 14
for i in range(len(df_nnzero.groupby(by="location"))):
    if (df_nnzero.groupby(by="location").count() > threshold)["date"][i] == True:
        x += 1
print(" {} country have more than {} day data".format(x,threshold))


for i in range(len(df_nnzero.groupby(by="location"))):
    if (df_nnzero.groupby(by="location").count() > threshold)["date"][i] == False:
        y += 1
print(" {} country have less than {} day data".format(y,threshold))
# Out:
#  181 country have more than 14 day data
#  24 country have less than 14 day data

# %% [markdown]
# In our model we need to have at least one mounth data for a country to add it to our dataset. Threshold is
# adjustable so we can change it whenever we want.

# %%
(df_nnzero.groupby(by="location").count() > threshold)
# Out:
#              date  new_cases  new_deaths  total_cases  total_deaths  \
# location
# Afghanistan  True       True        True         True          True
# Albania      True       True        True         True          True
# Algeria      True       True        True         True          True
# Andorra      True       True        True         True          True
# Angola       True       True        True         True          True
# ...           ...        ...         ...          ...           ...
# Venezuela    True       True        True         True          True
# Vietnam      True       True        True         True          True
# World        True       True        True         True          True
# Zambia       True       True        True         True          True
# Zimbabwe     True       True        True         True          True
#
#              continent  population_year  population
# location
# Afghanistan       True             True        True
# ...

# %%
df_nnzero.reset_index(inplace= True)

# %%
th_country_list = list()
for i in range(len(df_nnzero.groupby(by="location"))):
    if ((df_nnzero.groupby(by="location").count()).date[i] > threshold) == True:
        th_country_list.append((df_nnzero.groupby(by="location").count()).index[i])
        
len(th_country_list)
# Out:
# 181

# %%
df_thresh = pd.DataFrame()
p=0
for i in range(len(df_nnzero["date"])):
    for country in th_country_list:
        if df_nnzero["location"][i]==country:
            df_thresh= df_thresh.append(df_nnzero[df_nnzero.index == i])

df_thresh.reset_index(inplace = True)

df_thresh
# Out:
#       level_0  index        date     location  new_cases  new_deaths  \
# 0           0     56  2020-02-25  Afghanistan          1           0
# 1           1     57  2020-02-26  Afghanistan          0           0
# 2           2     58  2020-02-27  Afghanistan          0           0
# 3           3     59  2020-02-28  Afghanistan          0           0
# 4           4     60  2020-02-29  Afghanistan          0           0
# ...       ...    ...         ...          ...        ...         ...
# 5935     6161   9136  2020-04-02     Zimbabwe          0           0
# 5936     6162   9137  2020-04-03     Zimbabwe          0           0
# 5937     6163   9138  2020-04-04     Zimbabwe          1           0
# 5938     6164   9139  2020-04-05     Zimbabwe          0           0
# 5939     6165   9140  2020-04-06     Zimbabwe          0           0
#
#       total_cases  total_deaths continent  population_year  population
# ...

# %% [markdown]
# Now clean unnecessary columns and location == "world"

# %%
del df_thresh["level_0"]
del df_thresh["index"]
del df_thresh["date"]
del df_thresh["population_year"]

df_thresh
# Out:
#          location  new_cases  new_deaths  total_cases  total_deaths continent  \
# 0     Afghanistan          1           0            1             0      Asia
# 1     Afghanistan          0           0            1             0      Asia
# 2     Afghanistan          0           0            1             0      Asia
# 3     Afghanistan          0           0            1             0      Asia
# 4     Afghanistan          0           0            1             0      Asia
# ...           ...        ...         ...          ...           ...       ...
# 5935     Zimbabwe          0           0            8             1    Africa
# 5936     Zimbabwe          0           0            8             1    Africa
# 5937     Zimbabwe          1           0            9             1    Africa
# 5938     Zimbabwe          0           0            9             1    Africa
# 5939     Zimbabwe          0           0            9             1    Africa
#
#       population
# ...

# %%
df_world = df_thresh[df_thresh["location"] =="World"]
df_world.reset_index(inplace=True) 
del df_world["index"]
df_world
# Out:
#    location  new_cases  new_deaths  total_cases  total_deaths continent  \
# 0     World         27           0           27             0     World
# 1     World          0           0           27             0     World
# 2     World          0           0           27             0     World
# 3     World         17           0           44             0     World
# 4     World          0           0           44             0     World
# ..      ...        ...         ...          ...           ...       ...
# 93    World      77128        4998       928436         46883     World
# 94    World      77987        4776      1006423         51659     World
# 95    World      81713        6623      1088136         58282     World
# 96    World      86516        6118      1174652         64400     World
# 97    World      69769        4576      1244421         68976     World
#
#     population
# 0   7707454496
# 1   7707454496
# 2   7707454496
# 3   7707454496
# 4   7707454496
# ...

# %%
df_thresh = df_thresh[df_thresh["location"] != "World"]

# %%
df_thresh
# Out:
#          location  new_cases  new_deaths  total_cases  total_deaths continent  \
# 0     Afghanistan          1           0            1             0      Asia
# 1     Afghanistan          0           0            1             0      Asia
# 2     Afghanistan          0           0            1             0      Asia
# 3     Afghanistan          0           0            1             0      Asia
# 4     Afghanistan          0           0            1             0      Asia
# ...           ...        ...         ...          ...           ...       ...
# 5935     Zimbabwe          0           0            8             1    Africa
# 5936     Zimbabwe          0           0            8             1    Africa
# 5937     Zimbabwe          1           0            9             1    Africa
# 5938     Zimbabwe          0           0            9             1    Africa
# 5939     Zimbabwe          0           0            9             1    Africa
#
#       population
# ...

# %%
df_thresh.to_csv("data_cleaned_thresholded.csv")
